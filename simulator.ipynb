# %%
import geojson

# %%
import numpy as np
import sys
from pyproj import Transformer, CRS
import random
import matplotlib.pyplot as plt
import common.coordinate as coordinate
from common.point import Point

# %% [markdown]
# # Simulation dataset

# %% [markdown]
# The part would be used to generate the dataset. We define the center, or the initial point from the center. Then we mark the trajectory

# %%
center = np.array([47.3830036, 8.5407393, 442])

# %%
n = 1000
mu = 0
sigma = 1

# %%
x_gps = np.zeros([100,3])
x_gps[0] = center
ps = np.random.randn(100,3) * sigma
for i in range(1,ps.shape[0]):
    x_gps[i] = x_gps[i-1] + ps[i]

# %% [markdown]
# ### GPS -> World

# %%
x_world = np.zeros([100,3])
for i in range(x_gps.shape[0]):
    x_world[i] = coordinate.gps2world(x_gps[i])

# %%
'''
@function: draw the 3d plot of dataset
@param: dataset - an array of x,y,z points
@return: a 3D plot of points
'''
def plot_3d(dataset):

    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')

    xs = dataset[:,0]
    ys = dataset[:,1]
    zs = dataset[:,2]
    ax.scatter(xs, ys, zs, marker='x')

    ax.set_xlabel('North')
    ax.set_ylabel('East')
    ax.set_zlabel('Latitude')

    plt.show()

# %%
plot_3d(x_gps)

# %%
plot_3d(x_world)

# %% [markdown]
# ### World -> Body

# %%
x_body = np.zeros(x_world.shape[0])
for i in range(x_wolrd.shape[0]):
    x_body[i] = world2body(angle=30, init=center,x_in=)
# Out:
#   File "<ipython-input-10-1e85282cc018>", line 3
#     x_body[i] = world2body(angle=30, init=center,x_in=)
#                                                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # MAVROS

# %%
from common.mavros import

# %%
import numpy as np
from scipy.spatial.transform import Rotation as R
r = R.from_quat(np.array([0, 0, np.sin(np.pi/4), np.cos(np.pi/4)]))

# %%
r.as_matrix()

# %% [markdown]
# # Fire Detection

# %%
from common.temperature import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-a2841217c540> in <module>()
# ----> 1 from common.temperature import *
#
# /home/ignis/workspace/operations/common/temperature.py in <module>()
# ----> 1 import rospy
#       2 from sensor_msgs.msg import Image
#       3 import cv2
#       4 from cv_bridge import CvBridge
#       5
#
# /opt/ros/melodic/lib/python2.7/dist-packages/rospy/__init__.py in <module>()
#      47 from std_msgs.msg import Header
#      48
# ---> 49 from .client import spin, myargv, init_node, \
#      50     get_published_topics, \
#      51     wait_for_message, \
#
# /opt/ros/melodic/lib/python2.7/dist-packages/rospy/client.py in <module>()
#      50 import rosgraph.names
#      51
# ---> 52 import roslib
#      53
#      54 import rospy.core
#
# /opt/ros/melodic/lib/python2.7/dist-packages/roslib/__init__.py in <module>()
# ...
